# %% [markdown]
# <img src="logo-catedra.png" width="400"> <img src="Logo-GIIATa-small.png" width="100">
# <div style="text-align: right"> _Por: Braulio Castro, Marcela Zhagui_ </div>
#
# # Inteligencia Artificial II
#
# Desarrollar una red neuronal que realice un proceso de clasificación de imágenes (íconos) que representan diferentes categorías.

# %% [markdown]
# # 1. El programa debe cargar los íconos del corpus de datos dado, considerando que son imágenes a colores (RGB, Red, Green y Blue) de 32 x 32 pixeles, como se puede apreciar en la Ilustración 1:
#
#
# |||
# |:---:|:---:|
# |  <img src="boat.png" width="64"> (a)| <img src="blade.png" width="64"> (b) |
# |  <img src="family.png" width="64"> (c) | <img src="building.png" width="64"> (d) |
#
# Ilustración 1. Ejemplos de íconos que representan “botes” (a), “espadas” (b), “familia” (c) y construcción (d).
#
# 2. Se deberán probar al menos 3 distintas estructuras de redes neuronales y funciones de activación, a fin de determinar cuál fue la mejor alternativa (considerando  número de neuronas, número de capas y funciones de activación).
# 3. El programa deberá dividir el corpus de imágenes en dos bloques: entrenamiento (train) y pruebas (test). Asimismo, deberá generar un reporte en formato PDF, Word o similar que contenga la siguiente información:
#     * Gráfica de precisión (datos entrenamiento versus datos de prueba), ver Ilustración 2.
#     * Gráfica de log loss (función de coste: entropía cruzada), ver Ilustración 3.
#     * Comparación de precisión y log loss de las diferentes opciones de red neuronal que ha probado.
#     * Matriz de confusión.
#
# ![Ilustración 2. ](Figure2.png)
#
# Ilustración 2. Ejemplo de la precisión de la Red Neuronal Artificial durante los procesos de entrenamiento y validación.
#
# ![Ilustración 3. xxx](Figure3.png)
#
# Ilustración 3. Ejemplo la curva de función de coste de la Red Neuronal Artificial. Se comparan los resultados del entrenamiento y de la validación.
#
# 4. El programa debe tener una función lista para realizar la prueba (test) con un conjunto de datos, en base a un directorio que se le pase (con la misma estructura de directorios que se le facilitaron para el entrenamiento). Esa función generará los siguientes datos en un informe en formato PDF, Word o similar:
#     * Gráfica de precisión (datos entrenamiento versus datos de prueba).
#     * Gráfica de log loss (función de coste: entropía cruzada).
#     * Comparación de precisión y log loss de las diferentes opciones de red neuronal que ha probado.
#     * Matriz de confusión.
#
# 5. Deberá realizar el siguiente análisis en base al proyecto:
#     * Determinar qué configuración de red neuronal fue más efectiva y qué funciones de transferencia tuvieron los mejores resultados.
#     * Mostrar cómo afecta el número de neuronas para el problema dado.
#     * Indicar qué estrategia de normalización de datos usó y cuál fue la razón de seleccionar dicha estrategia.
#     * Indicar qué funcionalidad extra investigó y la incorporó en el proyecto para mejorar la precisión en la clasificación de los íconos.
# 6. Criterios de evaluación:
#     * Correcto funcionamiento del programa, el sistema tiene como mínimo un 83% de precisión en la clasificación de los datos. El programa no sobre-entrena la red. → 60% del puntaje.
#     * Emplea correctamente las técnicas de preprocesamiento de datos, así como del diseño de la red neuronal y las diferentes alternativas de configuración  → 20% del puntaje.
#     * Aplica nuevas técnicas o extras que ha investigado que permiten mejorar el proceso → 20% del puntaje.

# %% [markdown]
# # Proceso:

# %%
##LIBRERIAS
from itertools import repeat
import numpy as np
import seaborn as sb
import matplotlib.pyplot as pp
import pandas as pd
from PIL import Image # Importamos la clase Image de la librería **pillow**
from matplotlib import image
import os
from os import listdir
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import tensorflow_model_optimization as tfmot

import keras
from keras.models import Sequential #RNA que tiene conexion hacia adelante
from keras.layers import Dense, Dropout, Flatten, MaxPooling2D, LeakyReLU #Capas de RNA
import keras.optimizers as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import keras
from keras.utils import to_categorical
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from sklearn.metrics import confusion_matrix
# %matplotlib inline

# %% [markdown]
# # 1. El programa debe cargar los íconos del corpus de datos dado, considerando que son imágenes a colores (RGB, Red, Green y Blue) de 32 x 32 pixeles

# %%
#Carga de los datos con Numpy
iconos = np.load('./Icons-50.npy', allow_pickle = True).item()
print('Total de Muestras::::::::', len(iconos['image']))

#Dividimos la muestras en entradas y salidas
entrada = iconos['image']
salida = iconos['class']
# Out:
# Total de Muestras:::::::: 10000

# %%
#Cargamos las categorias en orden 
listaCategorias = os.listdir('./Icons-50')
listaCategorias.sort(key = str.lower)
categorias = pd.DataFrame(listaCategorias)
print('Total de Categorias ::::',len(categorias))
categorias
# Out:
# Total de Categorias :::: 50
#                      0
# 0             airplane
# 1     arrow_directions
# 2                 ball
# 3               biking
# 4                 bird
# 5                blade
# 6                 boat
# 7                books
# 8             building
# 9           bunny_ears
# 10        cartwheeling
# 11               clock
# 12               cloud
# 13                disk
# 14              drinks
# 15        emotion_face
# 16            envelope
# 17              family
# 18          fast_train
# 19              feline
# 20                flag
# 21              flower
# 22            footwear
# 23             golfing
# 24                hand
# 25                 hat
# 26               heart
# 27       holding_hands
# 28  japanese_ideograph
# 29                kiss
# 30                lock
# 31             mailbox
# 32      marine_animals
# 33               medal
# 34               money
# 35              monkey
# 36                moon
# 37            mountain
# 38             numbers
# 39               phone
# 40       prohibit_sign
# 41                star
# 42             surfing
# 43                tree
# 44            umbrella
# 45             vehicle
# 46          water_polo
# 47              worker
# 48           wrestling
# 49     writing_utensil

# %%
##TRASFORMAMOS LOS DATOS para el modelo 
# La Dimensión de cada ícono es de (3, 32, 32), en total tenemos 3072 columnas por cada ícono
TOTAL_COLUMNAS = 3072

#3D a 1D
entrada = np.array(list(map(lambda m: m.reshape(1, -1), entrada)))
entrada = np.array(list(map(lambda m: m.reshape(TOTAL_COLUMNAS), entrada)))

#vista
entrada = pd.DataFrame(entrada)

#Datos de Prueba 30% del total de las muestras
aux = np.random.rand(len(entrada)) < 0.2
prueba_a = entrada[aux]

salida = np.array([salida]).reshape(-1, 1)
prueba_b = salida[aux]
prueba_a.insert(3072, 3072,prueba_b)

#Guardamos 
prueba_a.to_csv('prueba.data', sep = ',', index = False)

# %% [markdown]
# # 2. El programa deberá dividir el corpus de imágenes en dos bloques: entrenamiento (train) y pruebas (test).

# %%
#Datos de Entrenamiento y Pruebas 
X_train, X_test, y_train, y_test = train_test_split(
    entrada, salida,
    test_size = 0.3, stratify = iconos['class'],
    random_state = 251
)
print('Training data shape : ', X_train.shape, y_train.shape)
print('Testing data shape : ', X_test.shape, y_test.shape)
# Out:
# Training data shape :  (7000, 3072) (7000, 1)
# Testing data shape :  (3000, 3072) (3000, 1)

# %% [markdown]
# # Normalización

# %%
#Escalamos los datos mediante la estrategia estandar
escalador = StandardScaler()
X_train = escalador.fit_transform(X_train)
X_test = escalador.fit_transform(X_test)

#Convertimos las salidas en arreglos
y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# # 3. Se deberán probar al menos 3 distintas estructuras de redes neuronales y funciones de activación, a fin de determinar cuál fue la mejor alternativa (considerando número de neuronas, número de capas y funciones de activación).

# %% [markdown]
# Función para entrenar los modelos

# %%
adam = tf.Adam(
    learning_rate=0.002,
    beta_1=0.9,
    beta_2=0.988,
    epsilon=1e-05,
    amsgrad=False,
)

def TEST1(modelo, X_train, X_test, y_train, y_test):
    modelo.compile(
        loss = 'sparse_categorical_crossentropy', 
        optimizer = adam, 
        metrics = ['accuracy']
    )
    historial = modelo.fit(
        X_train,
        y_train,
        validation_data = (X_test, y_test),
        epochs = 100, 
        batch_size = 140,
        verbose = 1
    )
    return (modelo, historial)

# %%
#Primera propuesta de red neuronal artificial
model1 = keras.Sequential([
    keras.layers.Flatten(input_shape=(3072, )),
    keras.layers.Dense(425, activation='softsign'),
    keras.layers.Dense(50, activation='softmax')
])
model1.summary()
model1_entrenado, historial1 = TEST1(model1, X_train, X_test, y_train, y_test)
import matplotlib.pyplot as pp
# %matplotlib inline
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 425)               1306025
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                21300
# =================================================================
# Total params: 1,327,325
# Trainable params: 1,327,325
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 50/50 [==============================] - 3s 59ms/step - loss: 1.8393 - accuracy: 0.5590 - val_loss: 1.3554 - val_accuracy: 0.6723
# Epoch 2/100
# 50/50 [==============================] - 2s 44ms/step - loss: 1.0228 - accuracy: 0.7540 - val_loss: 1.1439 - val_accuracy: 0.7253
# Epoch 3/100
# 50/50 [==============================] - 2s 31ms/step - loss: 0.7377 - accuracy: 0.8244 - val_loss: 1.0348 - val_accuracy: 0.7493
# Epoch 4/100
# 50/50 [==============================] - 1s 25ms/step - loss: 0.5539 - accuracy: 0.8731 - val_loss: 0.9578 - val_accuracy: 0.7670
# Epoch 5/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.4221 - accuracy: 0.9040 - val_loss: 0.9126 - val_accuracy: 0.7797
# Epoch 6/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.3278 - accuracy: 0.9287 - val_loss: 0.8823 - val_accuracy: 0.7900
# Epoch 7/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.2396 - accuracy: 0.9527 - val_loss: 0.8492 - val_accuracy: 0.7943
# Epoch 8/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1819 - accuracy: 0.9677 - val_loss: 0.8780 - val_accuracy: 0.7883
# Epoch 9/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1537 - accuracy: 0.9730 - val_loss: 0.8761 - val_accuracy: 0.7910
# Epoch 10/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1355 - accuracy: 0.9774 - val_loss: 0.8776 - val_accuracy: 0.7957
# Epoch 11/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.1118 - accuracy: 0.9807 - val_loss: 0.8625 - val_accuracy: 0.7940
# Epoch 12/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.1071 - accuracy: 0.9811 - val_loss: 0.8775 - val_accuracy: 0.7947
# Epoch 13/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0850 - accuracy: 0.9866 - val_loss: 0.8853 - val_accuracy: 0.7960
# Epoch 14/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0803 - accuracy: 0.9854 - val_loss: 0.8881 - val_accuracy: 0.7987
# Epoch 15/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0674 - accuracy: 0.9899 - val_loss: 0.8663 - val_accuracy: 0.8147
# Epoch 16/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0603 - accuracy: 0.9894 - val_loss: 0.8966 - val_accuracy: 0.8070
# Epoch 17/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0579 - accuracy: 0.9897 - val_loss: 0.9210 - val_accuracy: 0.8040
# Epoch 18/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0592 - accuracy: 0.9900 - val_loss: 0.9315 - val_accuracy: 0.7980
# Epoch 19/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0601 - accuracy: 0.9899 - val_loss: 0.9474 - val_accuracy: 0.7963
# Epoch 20/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0521 - accuracy: 0.9904 - val_loss: 0.9197 - val_accuracy: 0.7983
# Epoch 21/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0431 - accuracy: 0.9933 - val_loss: 0.9051 - val_accuracy: 0.8087
# Epoch 22/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0313 - accuracy: 0.9959 - val_loss: 0.9590 - val_accuracy: 0.7927
# Epoch 23/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0387 - accuracy: 0.9931 - val_loss: 0.9249 - val_accuracy: 0.8090
# Epoch 24/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0390 - accuracy: 0.9933 - val_loss: 0.9406 - val_accuracy: 0.8030
# Epoch 25/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0389 - accuracy: 0.9931 - val_loss: 0.9497 - val_accuracy: 0.8093
# Epoch 26/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0353 - accuracy: 0.9923 - val_loss: 0.9869 - val_accuracy: 0.7983
# Epoch 27/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0428 - accuracy: 0.9917 - val_loss: 0.9792 - val_accuracy: 0.8033
# Epoch 28/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0393 - accuracy: 0.9926 - val_loss: 1.0222 - val_accuracy: 0.7917
# Epoch 29/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0335 - accuracy: 0.9936 - val_loss: 1.0062 - val_accuracy: 0.8077
# Epoch 30/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0286 - accuracy: 0.9954 - val_loss: 1.0037 - val_accuracy: 0.8007
# Epoch 31/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0373 - accuracy: 0.9904 - val_loss: 1.0144 - val_accuracy: 0.7983
# Epoch 32/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0312 - accuracy: 0.9957 - val_loss: 1.0277 - val_accuracy: 0.8023
# Epoch 33/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0207 - accuracy: 0.9967 - val_loss: 1.0191 - val_accuracy: 0.8067
# Epoch 34/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0141 - accuracy: 0.9979 - val_loss: 1.0254 - val_accuracy: 0.8000
# Epoch 35/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 1.0266 - val_accuracy: 0.8087
# Epoch 36/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0163 - accuracy: 0.9966 - val_loss: 1.0558 - val_accuracy: 0.8007
# Epoch 37/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0484 - accuracy: 0.9881 - val_loss: 1.1314 - val_accuracy: 0.7713
# Epoch 38/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0511 - accuracy: 0.9883 - val_loss: 1.0462 - val_accuracy: 0.7970
# Epoch 39/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0325 - accuracy: 0.9944 - val_loss: 1.0208 - val_accuracy: 0.8033
# Epoch 40/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0244 - accuracy: 0.9946 - val_loss: 1.0579 - val_accuracy: 0.8023
# Epoch 41/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0187 - accuracy: 0.9960 - val_loss: 1.0573 - val_accuracy: 0.8063
# Epoch 42/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0146 - accuracy: 0.9963 - val_loss: 1.0384 - val_accuracy: 0.8040
# Epoch 43/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0135 - accuracy: 0.9977 - val_loss: 1.0560 - val_accuracy: 0.8000
# Epoch 44/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0147 - accuracy: 0.9970 - val_loss: 1.0673 - val_accuracy: 0.7997
# Epoch 45/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0299 - accuracy: 0.9930 - val_loss: 1.1685 - val_accuracy: 0.7900
# Epoch 46/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0540 - accuracy: 0.9857 - val_loss: 1.1424 - val_accuracy: 0.7857
# Epoch 47/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0271 - accuracy: 0.9947 - val_loss: 1.1109 - val_accuracy: 0.8027
# Epoch 48/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0148 - accuracy: 0.9976 - val_loss: 1.0616 - val_accuracy: 0.8073
# Epoch 49/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0091 - accuracy: 0.9983 - val_loss: 1.0879 - val_accuracy: 0.8077
# Epoch 50/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0114 - accuracy: 0.9974 - val_loss: 1.1167 - val_accuracy: 0.7990
# Epoch 51/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 1.1159 - val_accuracy: 0.7993
# Epoch 52/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0229 - accuracy: 0.9956 - val_loss: 1.1738 - val_accuracy: 0.7917
# Epoch 53/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0185 - accuracy: 0.9956 - val_loss: 1.1289 - val_accuracy: 0.7980
# Epoch 54/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0181 - accuracy: 0.9961 - val_loss: 1.1468 - val_accuracy: 0.7930
# Epoch 55/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0177 - accuracy: 0.9957 - val_loss: 1.1353 - val_accuracy: 0.8013
# Epoch 56/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0130 - accuracy: 0.9976 - val_loss: 1.1192 - val_accuracy: 0.8090
# Epoch 57/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0094 - accuracy: 0.9983 - val_loss: 1.1052 - val_accuracy: 0.8077
# Epoch 58/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 1.1018 - val_accuracy: 0.8120
# Epoch 59/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 1.1079 - val_accuracy: 0.8137
# Epoch 60/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 1.1163 - val_accuracy: 0.8130
# Epoch 61/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0080 - accuracy: 0.9983 - val_loss: 1.1800 - val_accuracy: 0.8017
# Epoch 62/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0144 - accuracy: 0.9969 - val_loss: 1.2109 - val_accuracy: 0.7960
# Epoch 63/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0510 - accuracy: 0.9843 - val_loss: 1.1753 - val_accuracy: 0.7953
# Epoch 64/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0281 - accuracy: 0.9933 - val_loss: 1.1944 - val_accuracy: 0.7927
# Epoch 65/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0153 - accuracy: 0.9971 - val_loss: 1.1672 - val_accuracy: 0.8017
# Epoch 66/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0101 - accuracy: 0.9981 - val_loss: 1.1421 - val_accuracy: 0.8097
# Epoch 67/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 1.1490 - val_accuracy: 0.8137
# Epoch 68/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 1.2080 - val_accuracy: 0.7950
# Epoch 69/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0196 - accuracy: 0.9951 - val_loss: 1.2231 - val_accuracy: 0.7920
# Epoch 70/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0166 - accuracy: 0.9967 - val_loss: 1.1862 - val_accuracy: 0.8000
# Epoch 71/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0182 - accuracy: 0.9961 - val_loss: 1.2152 - val_accuracy: 0.7983
# Epoch 72/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0113 - accuracy: 0.9979 - val_loss: 1.1714 - val_accuracy: 0.7983
# Epoch 73/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0073 - accuracy: 0.9983 - val_loss: 1.1763 - val_accuracy: 0.8053
# Epoch 74/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0064 - accuracy: 0.9987 - val_loss: 1.1773 - val_accuracy: 0.8097
# Epoch 75/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 1.1955 - val_accuracy: 0.8053
# Epoch 76/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 1.1700 - val_accuracy: 0.8093
# Epoch 77/100
# 50/50 [==============================] - 1s 21ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 1.1706 - val_accuracy: 0.8070
# Epoch 78/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 1.1739 - val_accuracy: 0.8090
# Epoch 79/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 1.1712 - val_accuracy: 0.8160
# Epoch 80/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0186 - accuracy: 0.9941 - val_loss: 1.2786 - val_accuracy: 0.7820
# Epoch 81/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0578 - accuracy: 0.9831 - val_loss: 1.3036 - val_accuracy: 0.7787
# Epoch 82/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0312 - accuracy: 0.9921 - val_loss: 1.2300 - val_accuracy: 0.7973
# Epoch 83/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0120 - accuracy: 0.9981 - val_loss: 1.2352 - val_accuracy: 0.7967
# Epoch 84/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 1.1895 - val_accuracy: 0.8053
# Epoch 85/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 1.1897 - val_accuracy: 0.8097
# Epoch 86/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 1.2102 - val_accuracy: 0.8047
# Epoch 87/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 1.2196 - val_accuracy: 0.8067
# Epoch 88/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 1.2554 - val_accuracy: 0.8037
# Epoch 89/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0167 - accuracy: 0.9959 - val_loss: 1.3717 - val_accuracy: 0.7743
# Epoch 90/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.0419 - accuracy: 0.9880 - val_loss: 1.3493 - val_accuracy: 0.7813
# Epoch 91/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0307 - accuracy: 0.9913 - val_loss: 1.3111 - val_accuracy: 0.7883
# Epoch 92/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0123 - accuracy: 0.9976 - val_loss: 1.2624 - val_accuracy: 0.7920
# Epoch 93/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0050 - accuracy: 0.9993 - val_loss: 1.2516 - val_accuracy: 0.7990
# Epoch 94/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 1.2396 - val_accuracy: 0.8027
# Epoch 95/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 1.2535 - val_accuracy: 0.7983
# Epoch 96/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 1.2680 - val_accuracy: 0.7987
# Epoch 97/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0044 - accuracy: 0.9983 - val_loss: 1.2498 - val_accuracy: 0.8037
# Epoch 98/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 1.2489 - val_accuracy: 0.7977
# Epoch 99/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 1.2575 - val_accuracy: 0.7997
# Epoch 100/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 1.2378 - val_accuracy: 0.8027

# %%
##Graficas RNA1
G = pp.figure(figsize = (15, 10))
gp1 = G.add_subplot(2, 2, 1)
gp1.plot(historial1.history['accuracy'])
gp1.plot(historial1.history['val_accuracy'])
gp1.set_title('Precisión RNA 1')
gp1.legend(['Entrenamiento','Test'], loc='lower right')
gp1.grid(True)


gp2 = G.add_subplot(2, 2, 2)
gp2.plot(historial1.history['loss'])
gp2.plot(historial1.history['val_loss'])
gp2.set_title('Loss RNA1')
gp2.legend(['Entrenamiento','Test'], loc='upper right')
gp2.grid(True)

filtro = G.get_window_extent().transformed(G.dpi_scale_trans.inverted())
G.savefig('RNA1.png', bbox_inches = filtro)

#Predicción
pred1 = model1_entrenado.predict(X_test,verbose=1)
pred1 = np.array(list(map(lambda m: [np.argmax(m)], pred1)))

#Matriz de confusión
matriz_confusion1 = confusion_matrix(
    pred1, 
    y_test,
)

#Graficamos la matriz
grafico_1 = pp.figure(figsize = (15,15))
sb.heatmap(matriz_confusion1, annot = True, cbar = False)
pp.show()


#Guardando la mátriz de confusión
grafico_1.savefig('MatrizConfusion1.png')

report1 = classification_report(np.argmax(y_test, axis=1), pred1)
print(report1)
# Out:
# 94/94 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.01      3000
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#            7       0.00      0.00      0.00         0
#            8       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           13       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           16       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           18       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           22       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00         0
#           25       0.00      0.00      0.00         0
#           26       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           31       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           33       0.00      0.00      0.00         0
#           34       0.00      0.00      0.00         0
#           35       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#           37       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#           39       0.00      0.00      0.00         0
#           40       0.00      0.00      0.00         0
#           41       0.00      0.00      0.00         0
#           42       0.00      0.00      0.00         0
#           43       0.00      0.00      0.00         0
#           44       0.00      0.00      0.00         0
#           45       0.00      0.00      0.00         0
#           46       0.00      0.00      0.00         0
#           47       0.00      0.00      0.00         0
#           48       0.00      0.00      0.00         0
#           49       0.00      0.00      0.00         0
#
#     accuracy                           0.00      3000
#    macro avg       0.02      0.00      0.00      3000
# weighted avg       1.00      0.00      0.01      3000
# C:\Users\Braulio Castro\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Segunda propuesta de red neuronal artificial
model2 = keras.Sequential([
    keras.layers.Flatten(input_shape=(3072, )),
    keras.layers.Dense(1050, activation='elu'),
    keras.layers.Dense(428, activation='sigmoid'),
    keras.layers.Dense(556, activation='softsign'),
    keras.layers.Dense(50, activation='sigmoid')
])
model2.summary()
model2_entrenado, historial2 = TEST1(model2,X_train, X_test, y_train, y_test)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1050)              3226650
# _________________________________________________________________
# dense_3 (Dense)              (None, 428)               449828
# _________________________________________________________________
# dense_4 (Dense)              (None, 556)               238524
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                27850
# =================================================================
# Total params: 3,942,852
# Trainable params: 3,942,852
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 50/50 [==============================] - 5s 94ms/step - loss: 2.3913 - accuracy: 0.3759 - val_loss: 1.5998 - val_accuracy: 0.5710
# Epoch 2/100
# 50/50 [==============================] - 3s 52ms/step - loss: 1.3346 - accuracy: 0.6406 - val_loss: 1.2791 - val_accuracy: 0.6623
# Epoch 3/100
# 50/50 [==============================] - 3s 59ms/step - loss: 1.0076 - accuracy: 0.7210 - val_loss: 1.1671 - val_accuracy: 0.6760
# Epoch 4/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.8344 - accuracy: 0.7671 - val_loss: 1.0518 - val_accuracy: 0.7237
# Epoch 5/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.6693 - accuracy: 0.8109 - val_loss: 0.9528 - val_accuracy: 0.7523
# Epoch 6/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.5673 - accuracy: 0.8416 - val_loss: 0.9449 - val_accuracy: 0.7567
# Epoch 7/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.5074 - accuracy: 0.8620 - val_loss: 0.9282 - val_accuracy: 0.7620
# Epoch 8/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.4714 - accuracy: 0.8617 - val_loss: 0.9022 - val_accuracy: 0.7687
# Epoch 9/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.4085 - accuracy: 0.8827 - val_loss: 0.9347 - val_accuracy: 0.7697
# Epoch 10/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.3943 - accuracy: 0.8866 - val_loss: 0.9627 - val_accuracy: 0.7553
# Epoch 11/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.3357 - accuracy: 0.9031 - val_loss: 0.8985 - val_accuracy: 0.7823
# Epoch 12/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3120 - accuracy: 0.9066 - val_loss: 0.9225 - val_accuracy: 0.7827
# Epoch 13/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3025 - accuracy: 0.9104 - val_loss: 0.8883 - val_accuracy: 0.7890
# Epoch 14/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.2985 - accuracy: 0.9106 - val_loss: 0.9541 - val_accuracy: 0.7760
# Epoch 15/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.2838 - accuracy: 0.9151 - val_loss: 0.9408 - val_accuracy: 0.7810
# Epoch 16/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2864 - accuracy: 0.9130 - val_loss: 0.9536 - val_accuracy: 0.7800
# Epoch 17/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.2706 - accuracy: 0.9136 - val_loss: 0.9992 - val_accuracy: 0.7767
# Epoch 18/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2937 - accuracy: 0.9097 - val_loss: 1.0639 - val_accuracy: 0.7617
# Epoch 19/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.2817 - accuracy: 0.9131 - val_loss: 0.9725 - val_accuracy: 0.7803
# Epoch 20/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.2325 - accuracy: 0.9276 - val_loss: 0.9710 - val_accuracy: 0.7930
# Epoch 21/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2305 - accuracy: 0.9270 - val_loss: 0.9875 - val_accuracy: 0.7830
# Epoch 22/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2176 - accuracy: 0.9336 - val_loss: 1.0004 - val_accuracy: 0.7717
# Epoch 23/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.2468 - accuracy: 0.9240 - val_loss: 1.0382 - val_accuracy: 0.7783
# Epoch 24/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2589 - accuracy: 0.9196 - val_loss: 0.9952 - val_accuracy: 0.7833
# Epoch 25/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.2595 - accuracy: 0.9156 - val_loss: 0.9650 - val_accuracy: 0.7977
# Epoch 26/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2278 - accuracy: 0.9299 - val_loss: 1.0394 - val_accuracy: 0.7767
# Epoch 27/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2256 - accuracy: 0.9260 - val_loss: 1.0560 - val_accuracy: 0.7727
# Epoch 28/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.2096 - accuracy: 0.9321 - val_loss: 1.0017 - val_accuracy: 0.7857
# Epoch 29/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2196 - accuracy: 0.9294 - val_loss: 1.0553 - val_accuracy: 0.7793
# Epoch 30/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2037 - accuracy: 0.9354 - val_loss: 0.9971 - val_accuracy: 0.7873
# Epoch 31/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.1796 - accuracy: 0.9437 - val_loss: 0.9932 - val_accuracy: 0.7880
# Epoch 32/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.2060 - accuracy: 0.9344 - val_loss: 1.0633 - val_accuracy: 0.7737
# Epoch 33/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.2019 - accuracy: 0.9347 - val_loss: 1.0737 - val_accuracy: 0.7777
# Epoch 34/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2177 - accuracy: 0.9291 - val_loss: 1.0642 - val_accuracy: 0.7790
# Epoch 35/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.2184 - accuracy: 0.9301 - val_loss: 1.0461 - val_accuracy: 0.7733
# Epoch 36/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1933 - accuracy: 0.9384 - val_loss: 1.0692 - val_accuracy: 0.7787
# Epoch 37/100
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1648 - accuracy: 0.9461 - val_loss: 1.1183 - val_accuracy: 0.7763
# Epoch 38/100
# 50/50 [==============================] - 3s 68ms/step - loss: 0.2003 - accuracy: 0.9363 - val_loss: 1.1910 - val_accuracy: 0.7630
# Epoch 39/100
# 50/50 [==============================] - 3s 59ms/step - loss: 0.2163 - accuracy: 0.9277 - val_loss: 1.0653 - val_accuracy: 0.7723
# Epoch 40/100
# 50/50 [==============================] - 3s 60ms/step - loss: 0.1925 - accuracy: 0.9391 - val_loss: 1.0612 - val_accuracy: 0.7667
# Epoch 41/100
# 50/50 [==============================] - 3s 63ms/step - loss: 0.2203 - accuracy: 0.9290 - val_loss: 1.1030 - val_accuracy: 0.7787
# Epoch 42/100
# 50/50 [==============================] - 3s 63ms/step - loss: 0.2001 - accuracy: 0.9370 - val_loss: 1.0971 - val_accuracy: 0.7777
# Epoch 43/100
# 50/50 [==============================] - 3s 63ms/step - loss: 0.1948 - accuracy: 0.9411 - val_loss: 1.1182 - val_accuracy: 0.7777
# Epoch 44/100
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1827 - accuracy: 0.9436 - val_loss: 1.0469 - val_accuracy: 0.7847
# Epoch 45/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.2153 - accuracy: 0.9316 - val_loss: 1.1752 - val_accuracy: 0.7703
# Epoch 46/100
# 50/50 [==============================] - 3s 56ms/step - loss: 0.2092 - accuracy: 0.9337 - val_loss: 1.1174 - val_accuracy: 0.7823
# Epoch 47/100
# 50/50 [==============================] - 3s 59ms/step - loss: 0.2065 - accuracy: 0.9330 - val_loss: 1.1120 - val_accuracy: 0.7757
# Epoch 48/100
# 50/50 [==============================] - 3s 70ms/step - loss: 0.2197 - accuracy: 0.9291 - val_loss: 1.1799 - val_accuracy: 0.7720
# Epoch 49/100
# 50/50 [==============================] - 3s 64ms/step - loss: 0.1966 - accuracy: 0.9370 - val_loss: 1.1631 - val_accuracy: 0.7710
# Epoch 50/100
# 50/50 [==============================] - 3s 65ms/step - loss: 0.2008 - accuracy: 0.9340 - val_loss: 1.0343 - val_accuracy: 0.7997
# Epoch 51/100
# 50/50 [==============================] - 3s 62ms/step - loss: 0.1753 - accuracy: 0.9434 - val_loss: 1.0293 - val_accuracy: 0.7910
# Epoch 52/100
# 50/50 [==============================] - 3s 68ms/step - loss: 0.1784 - accuracy: 0.9401 - val_loss: 1.1054 - val_accuracy: 0.7870
# Epoch 53/100
# 50/50 [==============================] - 3s 64ms/step - loss: 0.1774 - accuracy: 0.9407 - val_loss: 1.1437 - val_accuracy: 0.7707
# Epoch 54/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1814 - accuracy: 0.9420 - val_loss: 1.1300 - val_accuracy: 0.7823
# Epoch 55/100
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1873 - accuracy: 0.9419 - val_loss: 1.1752 - val_accuracy: 0.7677
# Epoch 56/100
# 50/50 [==============================] - 3s 56ms/step - loss: 0.2031 - accuracy: 0.9344 - val_loss: 1.0992 - val_accuracy: 0.7867
# Epoch 57/100
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1969 - accuracy: 0.9356 - val_loss: 1.1461 - val_accuracy: 0.7807
# Epoch 58/100
# 50/50 [==============================] - 3s 60ms/step - loss: 0.2027 - accuracy: 0.9334 - val_loss: 1.1012 - val_accuracy: 0.7807
# Epoch 59/100
# 50/50 [==============================] - 3s 56ms/step - loss: 0.1741 - accuracy: 0.9456 - val_loss: 1.1275 - val_accuracy: 0.7727
# Epoch 60/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.1887 - accuracy: 0.9409 - val_loss: 1.1493 - val_accuracy: 0.7727
# Epoch 61/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1890 - accuracy: 0.9386 - val_loss: 1.0997 - val_accuracy: 0.7863
# Epoch 62/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.2130 - accuracy: 0.9310 - val_loss: 1.1343 - val_accuracy: 0.7777
# Epoch 63/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1906 - accuracy: 0.9390 - val_loss: 1.1386 - val_accuracy: 0.7910
# Epoch 64/100
# 50/50 [==============================] - 3s 60ms/step - loss: 0.1863 - accuracy: 0.9427 - val_loss: 1.1409 - val_accuracy: 0.7857
# Epoch 65/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.1764 - accuracy: 0.9424 - val_loss: 1.0819 - val_accuracy: 0.7860
# Epoch 66/100
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1625 - accuracy: 0.9501 - val_loss: 1.1057 - val_accuracy: 0.7903
# Epoch 67/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.1734 - accuracy: 0.9433 - val_loss: 1.1304 - val_accuracy: 0.7890
# Epoch 68/100
# 50/50 [==============================] - 3s 63ms/step - loss: 0.1888 - accuracy: 0.9400 - val_loss: 1.1312 - val_accuracy: 0.7827
# Epoch 69/100
# 50/50 [==============================] - 3s 59ms/step - loss: 0.2008 - accuracy: 0.9349 - val_loss: 1.1482 - val_accuracy: 0.7850
# Epoch 70/100
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1850 - accuracy: 0.9389 - val_loss: 1.1121 - val_accuracy: 0.7817
# Epoch 71/100
# 50/50 [==============================] - 3s 56ms/step - loss: 0.1825 - accuracy: 0.9410 - val_loss: 1.1637 - val_accuracy: 0.7770
# Epoch 72/100
# 50/50 [==============================] - 3s 59ms/step - loss: 0.1810 - accuracy: 0.9434 - val_loss: 1.0861 - val_accuracy: 0.7840
# Epoch 73/100
# 50/50 [==============================] - 3s 58ms/step - loss: 0.1609 - accuracy: 0.9487 - val_loss: 1.0768 - val_accuracy: 0.7860
# Epoch 74/100
# 50/50 [==============================] - 3s 58ms/step - loss: 0.1580 - accuracy: 0.9499 - val_loss: 1.1727 - val_accuracy: 0.7887
# Epoch 75/100
# 50/50 [==============================] - 3s 58ms/step - loss: 0.1504 - accuracy: 0.9509 - val_loss: 1.1215 - val_accuracy: 0.7883
# Epoch 76/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.1341 - accuracy: 0.9551 - val_loss: 1.1043 - val_accuracy: 0.7953
# Epoch 77/100
# 50/50 [==============================] - 3s 58ms/step - loss: 0.1400 - accuracy: 0.9547 - val_loss: 1.1189 - val_accuracy: 0.7920
# Epoch 78/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1666 - accuracy: 0.9479 - val_loss: 1.1474 - val_accuracy: 0.7820
# Epoch 79/100
# 50/50 [==============================] - 3s 59ms/step - loss: 0.1734 - accuracy: 0.9431 - val_loss: 1.1086 - val_accuracy: 0.7837
# Epoch 80/100
# 50/50 [==============================] - 3s 58ms/step - loss: 0.1481 - accuracy: 0.9507 - val_loss: 1.0970 - val_accuracy: 0.7897
# Epoch 81/100
# 50/50 [==============================] - 3s 58ms/step - loss: 0.1662 - accuracy: 0.9470 - val_loss: 1.0812 - val_accuracy: 0.7953
# Epoch 82/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1607 - accuracy: 0.9476 - val_loss: 1.1455 - val_accuracy: 0.7817
# Epoch 83/100
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1513 - accuracy: 0.9523 - val_loss: 1.1800 - val_accuracy: 0.7747
# Epoch 84/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.1868 - accuracy: 0.9354 - val_loss: 1.1295 - val_accuracy: 0.7790
# Epoch 85/100
# 50/50 [==============================] - 3s 58ms/step - loss: 0.1718 - accuracy: 0.9414 - val_loss: 1.1400 - val_accuracy: 0.7833
# Epoch 86/100
# 50/50 [==============================] - 3s 56ms/step - loss: 0.1490 - accuracy: 0.9511 - val_loss: 1.1264 - val_accuracy: 0.7743
# Epoch 87/100
# 50/50 [==============================] - 3s 56ms/step - loss: 0.1573 - accuracy: 0.9476 - val_loss: 1.0941 - val_accuracy: 0.7843
# Epoch 88/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.1489 - accuracy: 0.9523 - val_loss: 1.1693 - val_accuracy: 0.7767
# Epoch 89/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1577 - accuracy: 0.9489 - val_loss: 1.1014 - val_accuracy: 0.7887
# Epoch 90/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.1550 - accuracy: 0.9486 - val_loss: 1.1477 - val_accuracy: 0.7870
# Epoch 91/100
# 50/50 [==============================] - 3s 58ms/step - loss: 0.1620 - accuracy: 0.9481 - val_loss: 1.1348 - val_accuracy: 0.7853
# Epoch 92/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1453 - accuracy: 0.9544 - val_loss: 1.0614 - val_accuracy: 0.7990
# Epoch 93/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1402 - accuracy: 0.9554 - val_loss: 1.0988 - val_accuracy: 0.7917
# Epoch 94/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1459 - accuracy: 0.9531 - val_loss: 1.1614 - val_accuracy: 0.7787
# Epoch 95/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.1630 - accuracy: 0.9466 - val_loss: 1.1424 - val_accuracy: 0.7823
# Epoch 96/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1555 - accuracy: 0.9499 - val_loss: 1.1036 - val_accuracy: 0.7870
# Epoch 97/100
# 50/50 [==============================] - 3s 56ms/step - loss: 0.1437 - accuracy: 0.9524 - val_loss: 1.0642 - val_accuracy: 0.7993
# Epoch 98/100
# 50/50 [==============================] - 3s 56ms/step - loss: 0.1357 - accuracy: 0.9560 - val_loss: 1.0687 - val_accuracy: 0.7970
# Epoch 99/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.1476 - accuracy: 0.9523 - val_loss: 1.1277 - val_accuracy: 0.7867
# Epoch 100/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.1480 - accuracy: 0.9513 - val_loss: 1.1131 - val_accuracy: 0.7910

# %%
##Graficas RNA2
G2 = pp.figure(figsize = (15, 10))
ge1 = G2.add_subplot(2, 2, 1)
ge1.plot(historial2.history['accuracy'])
ge1.plot(historial2.history['val_accuracy'])
ge1.set_title('Precisión RNA 2')
ge1.legend(['Entrenamiento','Test'], loc='lower right')
ge1.grid(True)


ge2 = G2.add_subplot(2, 2, 2)
ge2.plot(historial2.history['loss'])
ge2.plot(historial2.history['val_loss'])
ge2.set_title('Loss RNA2')
ge2.legend(['Entrenamiento','Test'], loc='upper right')
ge2.grid(True)

filtro = G2.get_window_extent().transformed(G2.dpi_scale_trans.inverted())
G2.savefig('RNA2.png', bbox_inches = filtro)


#Predicción
pred2 = model2_entrenado.predict(X_test)
pred2 = np.array(list(map(lambda m: [np.argmax(m)], pred2)))

#Matriz de confusión
matriz_confusion2 = confusion_matrix(
    pred2, 
    y_test,
)

#Graficamos la matriz
grafico_2 = pp.figure(figsize = (15,15))
sb.heatmap(matriz_confusion2, annot = True, cbar = False)
pp.show()

#Guardando la mátriz de confusión
grafico_2.savefig('MatrizConfusion2.png')

report2 = classification_report(np.argmax(y_test, axis=1), pred2)
print(report2)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00      3000
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#            7       0.00      0.00      0.00         0
#            8       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           13       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           16       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           18       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           22       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00         0
#           25       0.00      0.00      0.00         0
#           26       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           31       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           33       0.00      0.00      0.00         0
#           34       0.00      0.00      0.00         0
#           35       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#           37       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#           39       0.00      0.00      0.00         0
#           40       0.00      0.00      0.00         0
#           41       0.00      0.00      0.00         0
#           42       0.00      0.00      0.00         0
#           43       0.00      0.00      0.00         0
#           44       0.00      0.00      0.00         0
#           45       0.00      0.00      0.00         0
#           46       0.00      0.00      0.00         0
#           47       0.00      0.00      0.00         0
#           48       0.00      0.00      0.00         0
#           49       0.00      0.00      0.00         0
#
#     accuracy                           0.00      3000
#    macro avg       0.02      0.00      0.00      3000
# weighted avg       1.00      0.00      0.00      3000
# C:\Users\Braulio Castro\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Tercera propuesta de red neuronal artificial
model3 = Sequential()
model3.add(Dense(145, activation = 'exponential', input_shape = (3072, )))
model3.add(Dense(82, activation = 'exponential'))
model3.add(Dense(52, activation = 'exponential'))
model3.summary()
model3_entrenado, historial3 = TEST1(model3,X_train, X_test, y_train, y_test)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 145)               445585
# _________________________________________________________________
# dense_13 (Dense)             (None, 82)                11972
# _________________________________________________________________
# dense_14 (Dense)             (None, 52)                4316
# =================================================================
# Total params: 461,873
# Trainable params: 461,873
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 50/50 [==============================] - 2s 39ms/step - loss: nan - accuracy: 0.0077 - val_loss: nan - val_accuracy: 0.0077
# Epoch 2/100
# 50/50 [==============================] - 1s 28ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 3/100
# 50/50 [==============================] - 1s 23ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 4/100
# 50/50 [==============================] - 1s 22ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 5/100
# 50/50 [==============================] - 1s 22ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 6/100
# 50/50 [==============================] - 1s 22ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 7/100
# 50/50 [==============================] - 2s 31ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 8/100
# 50/50 [==============================] - 1s 24ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 9/100
# 50/50 [==============================] - 1s 23ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 10/100
# 50/50 [==============================] - 1s 23ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 11/100
# 50/50 [==============================] - 1s 21ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 12/100
# 50/50 [==============================] - 1s 22ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 13/100
# 50/50 [==============================] - 1s 20ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 14/100
# 50/50 [==============================] - 1s 19ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 15/100
# 50/50 [==============================] - 1s 19ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 16/100
# 50/50 [==============================] - 1s 18ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 17/100
# 50/50 [==============================] - 1s 17ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 18/100
# 50/50 [==============================] - 1s 18ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 19/100
# 50/50 [==============================] - 1s 18ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 20/100
# 50/50 [==============================] - 1s 18ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 21/100
# 50/50 [==============================] - 1s 15ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 22/100
# 50/50 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 23/100
# 50/50 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 24/100
# 50/50 [==============================] - 1s 15ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 25/100
# 50/50 [==============================] - 1s 15ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 26/100
# 50/50 [==============================] - 1s 17ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 27/100
# 50/50 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 28/100
# 50/50 [==============================] - 1s 12ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 29/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 30/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 31/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 32/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 33/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 34/100
# 50/50 [==============================] - 1s 12ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 35/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 36/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 37/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 38/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 39/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 40/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 41/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 42/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 43/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 44/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 45/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 46/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 47/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 48/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 49/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 50/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 51/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 52/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 53/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 54/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 55/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 56/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 57/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 58/100
# 50/50 [==============================] - 1s 12ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 59/100
# 50/50 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 60/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 61/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 62/100
# 50/50 [==============================] - 1s 12ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 63/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 64/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 65/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 66/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 67/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 68/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 69/100
# 50/50 [==============================] - 1s 12ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 70/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 71/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 72/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 73/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 74/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 75/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 76/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 77/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 78/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 79/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 80/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 81/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 82/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 83/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 84/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 85/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 86/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 87/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 88/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 89/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 90/100
# 50/50 [==============================] - 1s 11ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 91/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 92/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 93/100
# 50/50 [==============================] - 1s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 94/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 95/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 96/100
# 50/50 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 97/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 98/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 99/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077
# Epoch 100/100
# 50/50 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0076 - val_loss: nan - val_accuracy: 0.0077

# %%
##Graficas RNA3
G3 = pp.figure(figsize = (15, 10))
ga1 = G3.add_subplot(2, 2, 1)
ga1.plot(historial3.history['accuracy'])
ga1.plot(historial3.history['val_accuracy'])
ga1.set_title('Precisión RNA 3')
ga1.legend(['Entrenamiento','Test'], loc='lower right')
ga1.grid(True)


ga2 = G3.add_subplot(2, 2, 2)
ga2.plot(historial3.history['loss'])
ga2.plot(historial3.history['val_loss'])
ga2.set_title('Loss RNA3')
ga2.legend(['Entrenamiento','Test'], loc='upper right')
ga2.grid(True)

filtro = G3.get_window_extent().transformed(G3.dpi_scale_trans.inverted())
G3.savefig('RNA3.png', bbox_inches = filtro)
#Predicción
pred3 = model3_entrenado.predict(X_test)
pred3 = np.array(list(map(lambda m: [np.argmax(m)], pred3)))

#Matriz de confusión
matriz_confusion3 = confusion_matrix(
    pred3, 
    y_test,
)

#Graficamos la matriz
grafico_3 = pp.figure(figsize = (15,15))
sb.heatmap(matriz_confusion3, annot = True, cbar = False)
pp.show()
#Guardando la mátriz de confusión
grafico_3.savefig('MatrizConfusio3.png')

report3 = classification_report(np.argmax(y_test, axis=1), pred3)
print(report3)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3000
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
#Cuarta propuesta de red neuronal artificial
model4 = Sequential()
model4.add(Dense(300, activation = 'relu', input_shape = (3072, )))
model4.add(Dense(50, activation = 'sigmoid'))
model4.summary()
model4_entrenado, historial4 = TEST1(model4,X_train, X_test, y_train, y_test)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 300)               921900
# _________________________________________________________________
# dense_16 (Dense)             (None, 50)                15050
# =================================================================
# Total params: 936,950
# Trainable params: 936,950
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 50/50 [==============================] - 2s 46ms/step - loss: 3.1862 - accuracy: 0.2369 - val_loss: 2.7608 - val_accuracy: 0.2707
# Epoch 2/100
# 50/50 [==============================] - 2s 39ms/step - loss: 2.2385 - accuracy: 0.4190 - val_loss: 2.3263 - val_accuracy: 0.4820
# Epoch 3/100
# 50/50 [==============================] - 2s 39ms/step - loss: 1.5902 - accuracy: 0.6101 - val_loss: 2.0450 - val_accuracy: 0.6007
# Epoch 4/100
# 50/50 [==============================] - 2s 36ms/step - loss: 1.2481 - accuracy: 0.6817 - val_loss: 1.8428 - val_accuracy: 0.6657
# Epoch 5/100
# 50/50 [==============================] - 1s 25ms/step - loss: 0.9578 - accuracy: 0.7521 - val_loss: 1.8338 - val_accuracy: 0.6817
# Epoch 6/100
# 50/50 [==============================] - 1s 25ms/step - loss: 0.7592 - accuracy: 0.8099 - val_loss: 1.7980 - val_accuracy: 0.7133
# Epoch 7/100
# 50/50 [==============================] - 1s 23ms/step - loss: 0.7029 - accuracy: 0.8280 - val_loss: 1.7280 - val_accuracy: 0.7070
# Epoch 8/100
# 50/50 [==============================] - 1s 24ms/step - loss: 0.6092 - accuracy: 0.8457 - val_loss: 1.6984 - val_accuracy: 0.7327
# Epoch 9/100
# 50/50 [==============================] - 1s 23ms/step - loss: 0.5102 - accuracy: 0.8681 - val_loss: 1.5939 - val_accuracy: 0.7527
# Epoch 10/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.4745 - accuracy: 0.8767 - val_loss: 1.6471 - val_accuracy: 0.7537
# Epoch 11/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.4321 - accuracy: 0.8863 - val_loss: 1.6445 - val_accuracy: 0.7473
# Epoch 12/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.5002 - accuracy: 0.8799 - val_loss: 1.5917 - val_accuracy: 0.7480
# Epoch 13/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.4469 - accuracy: 0.8927 - val_loss: 1.6435 - val_accuracy: 0.7507
# Epoch 14/100
# 50/50 [==============================] - 1s 20ms/step - loss: 0.3768 - accuracy: 0.9009 - val_loss: 1.5821 - val_accuracy: 0.7713
# Epoch 15/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3454 - accuracy: 0.9141 - val_loss: 1.5439 - val_accuracy: 0.7633
# Epoch 16/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3841 - accuracy: 0.9054 - val_loss: 1.6438 - val_accuracy: 0.7670
# Epoch 17/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3322 - accuracy: 0.9164 - val_loss: 1.6439 - val_accuracy: 0.7623
# Epoch 18/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3264 - accuracy: 0.9246 - val_loss: 1.6836 - val_accuracy: 0.7587
# Epoch 19/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3751 - accuracy: 0.9069 - val_loss: 1.5981 - val_accuracy: 0.7677
# Epoch 20/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3882 - accuracy: 0.9093 - val_loss: 1.7101 - val_accuracy: 0.7590
# Epoch 21/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3316 - accuracy: 0.9180 - val_loss: 1.6386 - val_accuracy: 0.7727
# Epoch 22/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.3067 - accuracy: 0.9233 - val_loss: 1.5736 - val_accuracy: 0.7890
# Epoch 23/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3012 - accuracy: 0.9267 - val_loss: 1.6113 - val_accuracy: 0.7670
# Epoch 24/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3178 - accuracy: 0.9243 - val_loss: 1.6202 - val_accuracy: 0.7837
# Epoch 25/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3369 - accuracy: 0.9184 - val_loss: 1.6339 - val_accuracy: 0.7717
# Epoch 26/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3137 - accuracy: 0.9224 - val_loss: 1.6032 - val_accuracy: 0.7847
# Epoch 27/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3065 - accuracy: 0.9339 - val_loss: 1.5846 - val_accuracy: 0.7743
# Epoch 28/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.2732 - accuracy: 0.9326 - val_loss: 1.5102 - val_accuracy: 0.7910
# Epoch 29/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3117 - accuracy: 0.9321 - val_loss: 1.5048 - val_accuracy: 0.7960
# Epoch 30/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2872 - accuracy: 0.9319 - val_loss: 1.6550 - val_accuracy: 0.7723
# Epoch 31/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3215 - accuracy: 0.9283 - val_loss: 1.6401 - val_accuracy: 0.7693
# Epoch 32/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.2996 - accuracy: 0.9350 - val_loss: 1.5618 - val_accuracy: 0.7887
# Epoch 33/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.2706 - accuracy: 0.9351 - val_loss: 1.5794 - val_accuracy: 0.7873
# Epoch 34/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.2474 - accuracy: 0.9367 - val_loss: 1.5787 - val_accuracy: 0.7907
# Epoch 35/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.2401 - accuracy: 0.9379 - val_loss: 1.6382 - val_accuracy: 0.7810
# Epoch 36/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.2538 - accuracy: 0.9420 - val_loss: 1.5710 - val_accuracy: 0.7883
# Epoch 37/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.3557 - accuracy: 0.9333 - val_loss: 1.6364 - val_accuracy: 0.7820
# Epoch 38/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.4572 - accuracy: 0.9117 - val_loss: 1.8220 - val_accuracy: 0.7563
# Epoch 39/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4871 - accuracy: 0.9063 - val_loss: 1.7349 - val_accuracy: 0.7580
# Epoch 40/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3673 - accuracy: 0.9246 - val_loss: 1.6510 - val_accuracy: 0.7880
# Epoch 41/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3572 - accuracy: 0.9220 - val_loss: 1.6333 - val_accuracy: 0.7767
# Epoch 42/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3650 - accuracy: 0.9236 - val_loss: 1.8233 - val_accuracy: 0.7677
# Epoch 43/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3999 - accuracy: 0.9194 - val_loss: 1.7404 - val_accuracy: 0.7633
# Epoch 44/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.4132 - accuracy: 0.9170 - val_loss: 1.7497 - val_accuracy: 0.7663
# Epoch 45/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3934 - accuracy: 0.9184 - val_loss: 1.8633 - val_accuracy: 0.7673
# Epoch 46/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3725 - accuracy: 0.9241 - val_loss: 1.7146 - val_accuracy: 0.7730
# Epoch 47/100
# 50/50 [==============================] - 1s 19ms/step - loss: 0.3990 - accuracy: 0.9203 - val_loss: 1.8687 - val_accuracy: 0.7727
# Epoch 48/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.3637 - accuracy: 0.9294 - val_loss: 1.6737 - val_accuracy: 0.8050
# Epoch 49/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3687 - accuracy: 0.9321 - val_loss: 1.7916 - val_accuracy: 0.7680
# Epoch 50/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3984 - accuracy: 0.9119 - val_loss: 1.8782 - val_accuracy: 0.7637
# Epoch 51/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3539 - accuracy: 0.9236 - val_loss: 1.7416 - val_accuracy: 0.7727
# Epoch 52/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3754 - accuracy: 0.9273 - val_loss: 1.7749 - val_accuracy: 0.7670
# Epoch 53/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3680 - accuracy: 0.9207 - val_loss: 1.7473 - val_accuracy: 0.7770
# Epoch 54/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3125 - accuracy: 0.9301 - val_loss: 1.7521 - val_accuracy: 0.7800
# Epoch 55/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3320 - accuracy: 0.9319 - val_loss: 1.6928 - val_accuracy: 0.7833
# Epoch 56/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3539 - accuracy: 0.9281 - val_loss: 1.7631 - val_accuracy: 0.7710
# Epoch 57/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3743 - accuracy: 0.9290 - val_loss: 1.7224 - val_accuracy: 0.7820
# Epoch 58/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3290 - accuracy: 0.9354 - val_loss: 1.7873 - val_accuracy: 0.7820
# Epoch 59/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3077 - accuracy: 0.9381 - val_loss: 1.6781 - val_accuracy: 0.7797
# Epoch 60/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3159 - accuracy: 0.9344 - val_loss: 1.6006 - val_accuracy: 0.7933
# Epoch 61/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3300 - accuracy: 0.9307 - val_loss: 1.7373 - val_accuracy: 0.7830
# Epoch 62/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2926 - accuracy: 0.9369 - val_loss: 1.7528 - val_accuracy: 0.7823
# Epoch 63/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.3397 - accuracy: 0.9326 - val_loss: 1.6548 - val_accuracy: 0.7730
# Epoch 64/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3634 - accuracy: 0.9274 - val_loss: 1.6988 - val_accuracy: 0.7847
# Epoch 65/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.4090 - accuracy: 0.9274 - val_loss: 1.8067 - val_accuracy: 0.7667
# Epoch 66/100
# 50/50 [==============================] - 1s 14ms/step - loss: 0.3632 - accuracy: 0.9234 - val_loss: 1.7211 - val_accuracy: 0.7833
# Epoch 67/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3016 - accuracy: 0.9384 - val_loss: 1.6518 - val_accuracy: 0.7933
# Epoch 68/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3424 - accuracy: 0.9353 - val_loss: 1.8612 - val_accuracy: 0.7673
# Epoch 69/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3394 - accuracy: 0.9299 - val_loss: 1.8491 - val_accuracy: 0.7707
# Epoch 70/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3136 - accuracy: 0.9330 - val_loss: 1.7619 - val_accuracy: 0.7917
# Epoch 71/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.2883 - accuracy: 0.9409 - val_loss: 1.7022 - val_accuracy: 0.7977
# Epoch 72/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2618 - accuracy: 0.9451 - val_loss: 1.7541 - val_accuracy: 0.7897
# Epoch 73/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3453 - accuracy: 0.9250 - val_loss: 1.8313 - val_accuracy: 0.7783
# Epoch 74/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3742 - accuracy: 0.9241 - val_loss: 1.8536 - val_accuracy: 0.7690
# Epoch 75/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3642 - accuracy: 0.9320 - val_loss: 1.8550 - val_accuracy: 0.7857
# Epoch 76/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3410 - accuracy: 0.9354 - val_loss: 1.6419 - val_accuracy: 0.7940
# Epoch 77/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3245 - accuracy: 0.9381 - val_loss: 1.6734 - val_accuracy: 0.7943
# Epoch 78/100
# 50/50 [==============================] - 1s 18ms/step - loss: 0.2799 - accuracy: 0.9417 - val_loss: 1.6969 - val_accuracy: 0.7897
# Epoch 79/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2951 - accuracy: 0.9386 - val_loss: 1.6474 - val_accuracy: 0.7887
# Epoch 80/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2724 - accuracy: 0.9380 - val_loss: 1.6135 - val_accuracy: 0.7920
# Epoch 81/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2873 - accuracy: 0.9369 - val_loss: 1.6377 - val_accuracy: 0.7897
# Epoch 82/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3809 - accuracy: 0.9353 - val_loss: 1.6301 - val_accuracy: 0.8040
# Epoch 83/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.3276 - accuracy: 0.9397 - val_loss: 1.9245 - val_accuracy: 0.7907
# Epoch 84/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3018 - accuracy: 0.9351 - val_loss: 1.7656 - val_accuracy: 0.7730
# Epoch 85/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3126 - accuracy: 0.9320 - val_loss: 1.7329 - val_accuracy: 0.7780
# Epoch 86/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3162 - accuracy: 0.9331 - val_loss: 1.6709 - val_accuracy: 0.7730
# Epoch 87/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.2545 - accuracy: 0.9401 - val_loss: 1.7609 - val_accuracy: 0.7837
# Epoch 88/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2616 - accuracy: 0.9439 - val_loss: 1.7019 - val_accuracy: 0.7907
# Epoch 89/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2757 - accuracy: 0.9416 - val_loss: 1.8077 - val_accuracy: 0.7810
# Epoch 90/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2599 - accuracy: 0.9374 - val_loss: 1.8314 - val_accuracy: 0.7823
# Epoch 91/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2586 - accuracy: 0.9439 - val_loss: 1.6123 - val_accuracy: 0.8003
# Epoch 92/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.2307 - accuracy: 0.9469 - val_loss: 1.7200 - val_accuracy: 0.7940
# Epoch 93/100
# 50/50 [==============================] - 1s 16ms/step - loss: 0.2548 - accuracy: 0.9470 - val_loss: 1.6604 - val_accuracy: 0.8003
# Epoch 94/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2539 - accuracy: 0.9460 - val_loss: 1.7648 - val_accuracy: 0.7987
# Epoch 95/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3251 - accuracy: 0.9327 - val_loss: 1.8631 - val_accuracy: 0.7863
# Epoch 96/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3095 - accuracy: 0.9394 - val_loss: 1.9789 - val_accuracy: 0.7723
# Epoch 97/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.3112 - accuracy: 0.9416 - val_loss: 1.9206 - val_accuracy: 0.7853
# Epoch 98/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2897 - accuracy: 0.9389 - val_loss: 1.6641 - val_accuracy: 0.7970
# Epoch 99/100
# 50/50 [==============================] - 1s 15ms/step - loss: 0.2456 - accuracy: 0.9506 - val_loss: 1.6890 - val_accuracy: 0.8003
# Epoch 100/100
# 50/50 [==============================] - 1s 17ms/step - loss: 0.3240 - accuracy: 0.9439 - val_loss: 1.8290 - val_accuracy: 0.7793

# %%
##Graficas RNA4
G4 = pp.figure(figsize = (15, 10))
gb1 = G4.add_subplot(2, 2, 1)
gb1.plot(historial4.history['accuracy'])
gb1.plot(historial4.history['val_accuracy'])
gb1.set_title('Precisión RNA 4')
gb1.legend(['Entrenamiento','Test'], loc='lower right')
gb1.grid(True)


gb2 = G4.add_subplot(2, 2, 2)
gb2.plot(historial4.history['loss'])
gb2.plot(historial4.history['val_loss'])
gb2.set_title('Loss RNA4')
gb2.legend(['Entrenamiento','Test'], loc='upper right')
gb2.grid(True)

filtro = G4.get_window_extent().transformed(G4.dpi_scale_trans.inverted())
G4.savefig('RNA4.png', bbox_inches = filtro)
#Predicción
pred4 = model4_entrenado.predict(X_test)
pred4 = np.array(list(map(lambda m: [np.argmax(m)], pred4)))

#Matriz de confusión
matriz_confusion = confusion_matrix(
    pred4, 
    y_test,
)

#Graficamos la matriz
grafico_4 = pp.figure(figsize = (15,15))
sb.heatmap(matriz_confusion, annot = True, cbar = False)
pp.show()

#Guardando la mátriz de confusión
grafico_4.savefig('MatrizConfusion4.png')
report4 = classification_report(np.argmax(y_test, axis=1), pred4)
print(report4)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.03      0.06      3000
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#            5       0.00      0.00      0.00         0
#            6       0.00      0.00      0.00         0
#            7       0.00      0.00      0.00         0
#            8       0.00      0.00      0.00         0
#            9       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         0
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           13       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           16       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           18       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#           20       0.00      0.00      0.00         0
#           21       0.00      0.00      0.00         0
#           22       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00         0
#           25       0.00      0.00      0.00         0
#           26       0.00      0.00      0.00         0
#           27       0.00      0.00      0.00         0
#           28       0.00      0.00      0.00         0
#           29       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           31       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         0
#           33       0.00      0.00      0.00         0
#           34       0.00      0.00      0.00         0
#           35       0.00      0.00      0.00         0
#           36       0.00      0.00      0.00         0
#           37       0.00      0.00      0.00         0
#           38       0.00      0.00      0.00         0
#           39       0.00      0.00      0.00         0
#           40       0.00      0.00      0.00         0
#           41       0.00      0.00      0.00         0
#           42       0.00      0.00      0.00         0
#           43       0.00      0.00      0.00         0
#           44       0.00      0.00      0.00         0
#           45       0.00      0.00      0.00         0
#           46       0.00      0.00      0.00         0
#           47       0.00      0.00      0.00         0
#           48       0.00      0.00      0.00         0
#           49       0.00      0.00      0.00         0
#
#     accuracy                           0.03      3000
#    macro avg       0.02      0.00      0.00      3000
# weighted avg       1.00      0.03      0.06      3000
# C:\Users\Braulio Castro\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model1.save("entrenamiento1.h5")
model2.save("entrenamiento2.h5")
model3.save("entrenamiento3.h5")
model4.save("entrenamiento4.h5")

# %% [markdown]
# # Función para realizar la prueba (test) con un conjunto de datos, en base a un directorio que se le pase (con la misma estructura de directorios que se le facilitaron para el entrenamiento)

# %%
prueba = pd.read_csv('prueba.data', sep = ',')
#Datos Aleatorios 
muestras = prueba.sample(n = 20)

x = np.array(muestras.iloc[:, 0:3072])
y = np.array(muestras.iloc[:, -1])

#imagenes
grafico = pp.figure(figsize = (17, 5))
i = 1
for imagen in x:
    #Gráficos
    parte = grafico.add_subplot(2, 10, i)
    parte.set_title('icono ' + str(i))
    #1D a 3D
    imagen = np.reshape(imagen, (-1, 32, 32))
    imagen = np.rollaxis(imagen, 0, 3)
    pp.imshow(imagen)
    i += 1

pp.show()


resultados = model1_entrenado.evaluate(x, y, return_dict = True)
resultados
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 12.4361 - accuracy: 0.0000e+00
# {'loss': 12.436117172241211, 'accuracy': 0.0}

# %%
imagenes = np.array(x)

#Escalamos la muestra
x = escalador.fit_transform(x)

#Realizamos la predicción
predicciones = model1_entrenado.predict(x)

y_prediccion = np.array(list(map(lambda m: [np.argmax(m)], predicciones)))

#Mostramos las imágenes y sus predicciones
grafico = pp.figure(figsize = (17, 5))

i = 1
for muestra in imagenes:
    #Gráfico del modelo 1
    parte = grafico.add_subplot(2, 10, i)
    parte.set_title(listaCategorias[int(y_prediccion[i - 1])])
    
    #Convertimos el arreglo 1D a uno en 3D
    muestra = np.reshape(muestra, (-1, 32, 32))
    muestra = np.rollaxis(muestra, 0, 3)

    #Mostramos la imágen de ejemplo
    pp.imshow(muestra)
    i += 1

pp.show()

# %%
#Valores
rango_x = range(0, 99)
rango_y = []
rango_y.extend(repeat(resultados['accuracy'], 99))

#Realizamos la gráfica
G5 = pp.figure(figsize = (15, 10))
g1 = G5.add_subplot(2, 2, 1)
g1.set_title('RNA (Modelo 1)')
g1.plot(historial1.history['accuracy'], color = 'green')
g1.plot(rango_x, rango_y, linestyle = 'dashed',color = 'red')
g1.legend(['Entrenamiento', 'Prueba'], loc = 'lower right')
g1.grid(True)


rango_xx = range(0, 99)
rango_yy = []
rango_yy.extend(repeat(resultados['loss'], 99))

#Realizamos la gráfica
g2 = G5.add_subplot(2, 2, 2)
g2.set_title('RNA (Modelo 1)')
g2.plot(historial1.history['loss'], color = 'green')
g2.plot(rango_xx, rango_yy, linestyle = 'dashed',color = 'red')
g2.legend(['Entrenamiento', 'Prueba'], loc = 'upper right')
g2.grid(True)

filtro = G5.get_window_extent().transformed(G5.dpi_scale_trans.inverted())
G4.savefig('PRUEBA.jpg', bbox_inches = filtro)

matriz_confusion = confusion_matrix(
    y_prediccion, 
    y,
)

#Graficamos la matriz
grafico_c = pp.figure(figsize = (15,15))
sb.heatmap(matriz_confusion, annot = True, cbar = False)
grafico_c.savefig('MatrizConfusion-Prueba.jpg')
pp.show()

# %%
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt

pdf = PdfPages('Reporte1.pdf')
pdf.savefig(G)
pdf.savefig(grafico_1)
pdf.savefig(G2)
pdf.savefig(grafico_2)
pdf.savefig(G3)
pdf.savefig(grafico_3)
pdf.savefig(G4)
pdf.savefig(grafico_4)
pdf.close()

pdf = PdfPages('Reporte2.pdf')
pdf.savefig(G5)
pdf.savefig(grafico_c)
pdf.close()

# %% [markdown]
# ### CONV2D - Complemento

# %%
model = Sequential()
model.add(Conv2D(16, kernel_size=(3, 3), use_bias=True, activation='relu',padding='same', input_shape=(32, 32, 1)))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(filters=32, kernel_size=2, use_bias=True, padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2), padding='same'))
          
model.add(Conv2D(filters=64, kernel_size=2, use_bias=True, padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Dropout(0.5))
        
model.add(Conv2D(filters=128, kernel_size=2, use_bias=True, padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Dropout(0.5))  
          
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5)) 
model.add(Dense(46, activation='softmax'))          
#model.summary()
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-745b286723a8> in <module>
# ----> 1 model = Sequential()
#       2 model.add(Conv2D(16, kernel_size=(3, 3), use_bias=True, activation='relu',padding='same', input_shape=(32, 32, 1)))
#       3 model.add(MaxPooling2D((2, 2), padding='same'))
#       4
#       5 model.add(Conv2D(filters=32, kernel_size=2, use_bias=True, padding='same', activation='relu'))
#
# NameError: name 'Sequential' is not defined

# %%
historial = model.fit(X_train, y_train, validation_data = (X_test, y_test) ,epochs = 30, batch_size = 64)

# %%
y_predecido = model.predict(X_test)
predecidos = list()
for i in range(len(y_predecido)):
    predecidos.append(np.argmax(y_predecido[i]))

test = list()
for i in range(len(y_test)):
    test.append(np.argmax(y_test[i]))

#comparamos lo que predijo la red contra las salidas deseadas
precision = accuracy_score(predecidos, test)
print('Precision: ', (precision*100))
print(predecidos[992])
